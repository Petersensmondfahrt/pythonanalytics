# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import ords_prods_merge

ords_prods_merge = pd.read_pickle(r'/Users/davidscheider/anaconda_projects/Instacart Basket Analysis/02 Data/Prepared Data/ords_prods_merge_new_columns.pkl')

# %%
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 20)

# %%
df.head(10)
# Out:
#    Unnamed: 0  order_id  customer_id  order_number  orders_day_of_week  \
# 0           0   2539329            1             1                   2
# 1           0   2539329            1             1                   2
# 2           0   2539329            1             1                   2
# 3           0   2539329            1             1                   2
# 4           0   2539329            1             1                   2
# 5           1   2398795            1             2                   3
# 6           1   2398795            1             2                   3
# 7           1   2398795            1             2                   3
# 8           1   2398795            1             2                   3
# 9           1   2398795            1             2                   3
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# ...

# %%
df.groupby('product_name')

# %%
# write group by function

df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800198
# 2                17.091743
# 3                17.915512
# 4                17.894135
# 5                15.211405
# 6                15.382135
# 7                17.694969
# 8                16.458105
# 9                15.957942
# 10               20.091818
# 11               16.483488
# 12               15.615744
# 13               16.485481
# 14               17.516024
# 15               15.691875
# 16               18.014748
# 17               16.151227
# 18               19.603710
# 19               17.632479
# 20               17.139432
# 21               21.956893

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     14.800198
# 2     17.091743
# 3     17.915512
# 4     17.894135
# 5     15.211405
# 6     15.382135
# 7     17.694969
# 8     16.458105
# 9     15.957942
# 10    20.091818
# 11    16.483488
# 12    15.615744
# 13    16.485481
# 14    17.516024
# 15    15.691875
# 16    18.014748
# 17    16.151227
# 18    19.603710
# 19    17.632479
# 20    17.139432
# 21    21.956893
# Name: order_number, dtype: float64

# %%
# aggregate mean, min, max
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.800198   1  99
# 2                17.091743   1  98
# 3                17.915512   1  99
# 4                17.894135   1  99
# 5                15.211405   1  99
# 6                15.382135   1  99
# 7                17.694969   1  99
# 8                16.458105   1  91
# 9                15.957942   1  99
# 10               20.091818   1  99
# 11               16.483488   1  99
# 12               15.615744   1  99
# 13               16.485481   1  99
# 14               17.516024   1  99
# 15               15.691875   1  99
# 16               18.014748   1  99
# 17               16.151227   1  99
# 18               19.603710   1  99
# 19               17.632479   1  99
# 20               17.139432   1  99
# 21               21.956893   1  97

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['customer_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/bz/7hwgnc95287cp83lwy4gfzth0000gn/T/ipykernel_3521/1765234698.py:1: FutureWarning: The provided callable <function max at 0x106332480> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['customer_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0  order_id  customer_id  order_number  orders_day_of_week  \
# 0            0   2539329            1             1                   2
# 1            0   2539329            1             1                   2
# 2            0   2539329            1             1                   2
# 3            0   2539329            1             1                   2
# 4            0   2539329            1             1                   2
# 5            1   2398795            1             2                   3
# 6            1   2398795            1             2                   3
# 7            1   2398795            1             2                   3
# 8            1   2398795            1             2                   3
# 9            1   2398795            1             2                   3
# 10           1   2398795            1             2                   3
# 11           2    473747            1             3                   3
# ...

# %%
# I get an error for the line of code with ['user_id'], so I changed it to ['customer_id'] and it worked

ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 3
#       1 # I get an error for the line of code with ['user_id'], so I changed it to ['customer_id'] and it worked
# ----> 3 ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
# ...

# %%
# dont assign any options regarding the maximum number of rows to display
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0  order_id  customer_id  order_number  orders_day_of_week  \
# 0            0   2539329            1             1                   2
# 1            0   2539329            1             1                   2
# 2            0   2539329            1             1                   2
# 3            0   2539329            1             1                   2
# 4            0   2539329            1             1                   2
# 5            1   2398795            1             2                   3
# 6            1   2398795            1             2                   3
# 7            1   2398795            1             2                   3
# 8            1   2398795            1             2                   3
# 9            1   2398795            1             2                   3
# 10           1   2398795            1             2                   3
# 11           2    473747            1             3                   3
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15877395
# Loyal customer      10284396
# New customer         6244250
# Name: count, dtype: int64

# %%
ords_prods_merge[['customer_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     customer_id      loyalty_flag  order_number
# 0             1      New customer             1
# 1             1      New customer             1
# 2             1      New customer             1
# 3             1      New customer             1
# 4             1      New customer             1
# 5             1      New customer             2
# 6             1      New customer             2
# 7             1      New customer             2
# 8             1      New customer             2
# 9             1      New customer             2
# 10            1      New customer             2
# 11            1      New customer             3
# 12            1      New customer             3
# 13            1      New customer             3
# 14            1      New customer             3
# 15            1      New customer             3
# 16            1      New customer             4
# 17            1      New customer             4
# 18            1      New customer             4
# ...
