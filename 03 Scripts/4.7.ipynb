# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import ords_prods_merge

ords_prods_merge = pd.read_pickle(r'/Users/davidscheider/anaconda_projects/Instacart Basket Analysis/02 Data/Prepared Data/ords_prods_merge.pkl')

# %%
# define path

path = r'/Users/davidscheider/anaconda_projects/Instacart Basket Analysis'

# %%
# create smaller data subset

df = ords_prods_merge[:1000000]

# %%
# define function

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# use price_range funtion on df dataframe

df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/bz/7hwgnc95287cp83lwy4gfzth0000gn/T/ipykernel_5076/1735701206.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts()
# Out:
# price_range
# Mid-range product    673194
# Low-range product    314381
# High range            12425
# Name: count, dtype: int64

# %%
# check max price
df['prices'].max()
# Out:
# 99999.0

# %%
df['price_range'].valuecounts(dropna = False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/bz/7hwgnc95287cp83lwy4gfzth0000gn/T/ipykernel_5076/2255376595.py in ?()
# ----> 1 df['price_range'].valuecounts(dropna = False)
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'valuecounts'

# %%
# check shape of df
df.shape
# Out:
# (1000000, 18)

# %%
# define High-range product
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
# define Mid-range product
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
# define Low-range product
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts()
# Out:
# price_range_loc
# Mid-range product     673194
# Low-range product     314381
# High-range product     12425
# Name: count, dtype: int64

# %%
# define High-range product for ords_prods_merge dataframe 

ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
# define Mid-range product for ords_prods_merge dataframe 

ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
# define Low-range product for ords_prods_merge dataframe 
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# count values
ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     21861997
# Low-range product     10126366
# High-range product      417678
# Name: count, dtype: int64

# %%
# print frequency of the orders_day_of_week column
ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6204404
# 1    5660456
# 6    4496635
# 2    4213986
# 5    4205906
# 3    3840701
# 4    3783953
# Name: count, dtype: int64

# %%
# create for-loop for Busiest day, Least busy, and Regularly busy
result = []

for value in ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
# print result
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# create a new column within ords_prods_merge dataframe and set it equal to result
ords_prods_merge['busiest_day'] = result

# %%
# print the frequency of this new column and cross-check it with the frequency of “orders_day_of_week”
ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22417684
# Busiest day        6204404
# Least busy         3783953
# Name: count, dtype: int64

# %% [markdown]
# ## Exercise 4.7

# %%
# create for-loop for Busiest day, Least busy, and Regularly busy
result = []

for value in ords_prods_merge["orders_day_of_week"]:
  if value in [0, 1]:
    result.append("Busiest days")
  elif value in [3, 4]:
    result.append("Slowest days")
  else:
    result.append("Regular day")

# %%
# check result
result
# Out:
# ['Regular day',
#  'Regular day',
#  'Regular day',
#  'Regular day',
#  'Regular day',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regular day',
#  'Regular day',
#  'Regular day',
#  'Regular day',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
# ...

# %%
# create a new column within ords_prods_merge dataframe and set it equal to result
ords_prods_merge['Busiest_days'] = result

# %%
# print the frequency of this new column and cross-check it with the frequency of “orders_day_of_week”
ords_prods_merge['Busiest_days'].value_counts(dropna = False)
# Out:
# Busiest_days
# Regular day     12916527
# Busiest days    11864860
# Slowest days     7624654
# Name: count, dtype: int64

# %% [markdown]
# There are more regular and busy days as there are slow days

# %%
# check column that records the time
ords_prods_merge
# Out:
#           Unnamed: 0  order_id  customer_id  order_number  orders_day_of_week  \
# 0                  0   2539329            1             1                   2
# 1                  0   2539329            1             1                   2
# 2                  0   2539329            1             1                   2
# 3                  0   2539329            1             1                   2
# 4                  0   2539329            1             1                   2
# ...              ...       ...          ...           ...                 ...
# 32406036     3421081   2977660       206209            13                   1
# 32406037     3421081   2977660       206209            13                   1
# 32406038     3421081   2977660       206209            13                   1
# 32406039     3421081   2977660       206209            13                   1
# 32406040     3421081   2977660       206209            13                   1
#
# ...

# %%
#print frequency order_hour_of_day
ords_prods_merge['order_hour_of_day'].value_counts(dropna = False)
# Out:
# order_hour_of_day
# 10    2761862
# 11    2736242
# 14    2689251
# 15    2662246
# 13    2661057
# 12    2618613
# 16    2535313
# 9     2454273
# 17    2087721
# 8     1718182
# 18    1636566
# 19    1258352
# 20     976182
# 7      891082
# 21     795658
# 22     634247
# 23     402335
# 6      290500
# 0      218786
# 1      115706
# 5       87964
# 2       69377
# 4       53245
# 3       51281
# Name: count, dtype: int64

# %%
# create for-loop for busiest hours of the day
result = []

for value in ords_prods_merge["order_hour_of_day"]:
  if value in [10, 11, 14]:
    result.append("Most orders")
  elif value in [2, 4, 3]:
    result.append("Fewest orders")
  else:
    result.append("Average orders")

# %%
result
# Out:
# ['Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
# ...

# %%
# create a new column "busiest_period_of_day"
ords_prods_merge['busiest_period_of_day'] = result

# %%
# print the frequency of new column "busiest_period_of_day"
ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Average orders    24044783
# Most orders        8187355
# Fewest orders       173903
# Name: count, dtype: int64

# %%
# export to pickle file
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data','ords_prods_merge_new_columns.pkl'))
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
